# %%
pip install sqlalchemy psycopg2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: C:\Users\Admin\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from sqlalchemy import create_engine

# Connect to PostgreSQL
engine = create_engine("postgresql+psycopg2://postgres:12345@localhost:5433/flight_analytics")

# Test connection
with engine.connect() as conn:
    print("Connection successful!")
# Out:
# Connection successful!

# %%
# Load CSVs into dataframes
airports_df = pd.read_csv("airports_clean.csv")
flights_df  = pd.read_csv("flights_master.csv")
aircraft_df = pd.read_csv("aircraft.csv")
delays_df   = pd.read_csv("airport_delays.csv")

# Load into PostgreSQL tables
airports_df.to_sql("airport",        engine, if_exists="replace", index=False)
flights_df.to_sql("flights",         engine, if_exists="replace", index=False)
aircraft_df.to_sql("aircraft",       engine, if_exists="replace", index=False)
delays_df.to_sql("airport_delays",   engine, if_exists="replace", index=False)

print("All tables loaded successfully!")
# Out:
# All tables loaded successfully!
